# %% [markdown]
# ## Load the data and necessary libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt                                                                                                                 

# Load the data
df = pd.read_csv('Dev_data_to_be_shared 3\Dev_data_to_be_shared.csv')
df.head(5)
# Out:
#    account_number  bad_flag  onus_attribute_1  transaction_attribute_1  \
# 0               1         0               NaN                      NaN
# 1               2         0          221000.0                      0.0
# 2               3         0           25000.0                      0.0
# 3               4         0           86000.0                      0.0
# 4               5         0          215000.0                      0.0
#
#    transaction_attribute_2  transaction_attribute_3  transaction_attribute_4  \
# 0                      NaN                      NaN                      NaN
# 1                      0.0                      0.0                      0.0
# 2                      0.0                      0.0                      0.0
# 3                      0.0                      0.0                      0.0
# 4                      0.0                      0.0                      0.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96806 entries, 0 to 96805
# Columns: 1216 entries, account_number to onus_attribute_48
# dtypes: float64(1189), int64(27)
# memory usage: 898.1 MB

# %%
df = df.fillna(0)

# %%
df.describe()
# Out:
#        account_number      bad_flag  onus_attribute_1  \
# count    96806.000000  96806.000000      9.680600e+04
# mean     48403.500000      0.014173      1.140391e+05
# std      27945.629417      0.118203      1.634346e+05
# min          1.000000      0.000000      0.000000e+00
# 25%      24202.250000      0.000000      0.000000e+00
# 50%      48403.500000      0.000000      6.900000e+04
# 75%      72604.750000      0.000000      1.450000e+05
# max      96806.000000      1.000000      2.800000e+06
#
#        transaction_attribute_1  transaction_attribute_2  \
# count             96806.000000             96806.000000
# mean                  7.076295                 0.001632
# std                1301.809963                 0.102534
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# ...

# %% [markdown]
# #####
# * since,dataset contains many saprse values and many dimensions.so ,reduce it's dimensions{4} and target attribute is 'bad_flag'.
# * drop account_number as it is irrelevant.
# *

# %%
df = df.drop(columns=['account_number'],axis=1)

# %%
df['bad_flag'].value_counts()
# Out:
# bad_flag
# 0    95434
# 1     1372
# Name: count, dtype: int64

# %% [markdown]
# * since the no.of samples for '1' is low ,as it may lead to model's poor performance and always tend to predict the majority class.
# * so,increase the no.of 1's or decrease the no of 0's. perform oversampling and undersampling.
# * choosing \* Oversampling as it may increase the no.of instances and make the classes equal. we preferrably use SMOTE{Synthetic Minority Over-Sampling technique}.

# %% [markdown]
# ### Oversampling

# %%
from imblearn.over_sampling import SMOTE

# Assuming your data is in a pandas DataFrame named 'df'
# and the target variable is in the 'target_attribute' column

X = df.drop('bad_flag', axis=1)  # Features
X = X.fillna(0)
y = df['bad_flag']

# Create an instance of SMOTE
smote = SMOTE(random_state=42)

# Perform oversampling
X_resampled, y_resampled = smote.fit_resample(X, y)

# Print the class distribution after oversampling
print(pd.Series(y_resampled).value_counts())
# Out:
# bad_flag
# 0    95434
# 1    95434
# Name: count, dtype: int64

# %%
X_resampled.shape,y_resampled.shape
# Out:
# ((190868, 1214), (190868,))

# %% [markdown]
# #### Concatenate the similar columns

# %%
col_group = ['onus_attribute_','transaction_attribute_','bureau_enquiry_','bureau_']
df_sum = pd.DataFrame()

for group in col_group:
    
    #select the colummns which startswith similar name
    selected_column = [col for col in X_resampled.columns if col.startswith(group)]

    #sum those values of that columns
    df_sum[group] = X_resampled[selected_column].sum(axis=1)


print(df_sum.shape)
df_sum.head(4)
# Out:
# (190868, 4)
#    onus_attribute_  transaction_attribute_  bureau_enquiry_       bureau_
# 0        87.105460            0.000000e+00             15.0  1.780044e+06
# 1    268841.929401            3.131015e+06             69.0  1.237014e+07
# 2     34406.201635            2.874122e+05             98.0  1.443926e+06
# 3     88117.396714            5.907834e+05            245.0  2.464937e+06

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print(df_sum.describe())
print(df_sum.info())

# Check for missing values
print(df_sum.isnull().sum())

# Visualizations
# Histogram for each column
# Out:
#        onus_attribute_  transaction_attribute_  bureau_enquiry_       bureau_
# count     1.908680e+05            1.908680e+05    190868.000000  1.908680e+05
# mean      1.067412e+05            7.588101e+05       130.521238  1.215198e+07
# std       1.504186e+05            1.557452e+06       111.629097  4.593944e+07
# min      -8.735414e+06           -1.818868e+06         0.000000 -1.597344e+06
# 25%       2.696815e+04            1.260161e+05        45.864546  1.630163e+06
# 50%       6.976928e+04            4.667353e+05       106.085422  4.736921e+06
# 75%       1.362981e+05            1.010455e+06       188.000000  1.168706e+07
# max       1.459646e+07            3.017254e+08      1437.000000  7.040146e+09
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190868 entries, 0 to 190867
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   onus_attribute_         190868 non-null  float64
# ...

# %%
for col in df_sum.columns:
    plt.figure()
    sns.histplot(df_sum[col], bins=20)
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

# Pairplot to visualize relationships between columns
sns.pairplot(df_sum)
plt.show()

# Correlation matrix
correlation_matrix = df_sum.corr()
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### split the data into training and testing & perform scaling

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
X_train , X_test, y_train, y_test = train_test_split(df_sum, y_resampled, test_size=0.25, random_state=41)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((143151, 4), (47717, 4), (143151,), (47717,))

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_train
# Out:
# array([[-0.28581429, -0.22851993, -0.83349772, -0.23441462],
#        [-0.44463541, -0.48227958, -0.86535126, -0.08561977],
#        [-0.63146963, -0.48227958, -0.03953334, -0.19161954],
#        ...,
#        [-0.63563022, -0.48227958, -0.19265034, -0.22104829],
#        [-0.24180593,  0.37932318,  1.68170759, -0.12722099],
#        [ 0.21867865,  0.63669283,  0.75810028, -0.18087584]])

# %% [markdown]
# ### Model building {perform Ensemble learning}

# %%
model1 = RandomForestClassifier(n_estimators=250)
model2 = GradientBoostingClassifier()
model3 = LogisticRegression(penalty='l2',C=0.1)
model4 = SVC()
model5 = DecisionTreeClassifier()
model6 = KNeighborsClassifier(n_neighbors=3)

ensemble_model = VotingClassifier(estimators=[
    ('rf', model1),('lr',model3),('dtclf',model5),('knn',model6)
], voting='hard')

ensemble_model.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('rf', RandomForestClassifier(n_estimators=250)),
#                              ('lr', LogisticRegression(C=0.1)),
#                              ('dtclf', DecisionTreeClassifier()),
#                              ('knn', KNeighborsClassifier(n_neighbors=3))])

# %%
y_pred = ensemble_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Ensemble Model Accuracy:", accuracy)
# Out:
# Ensemble Model Accuracy: 0.8723096590313725

# %% [markdown]
# ### Metrics

# %%
from sklearn.metrics import precision_score,recall_score,f1_score
cfm = confusion_matrix(y_test,y_pred)
prec = precision_score(y_test,y_pred)
recall = recall_score(y_test,y_pred)
f1_s = f1_score(y_test,y_pred)

print('Confusion Matrix:',cfm)
print('Precision:',prec)
print('Recall:',recall)
print('F1 Score:',f1_s)
# Out:
# Confusion Matrix: [[20949  2912]
#  [ 3181 20675]]
# Precision: 0.8765421630559206
# Recall: 0.8666582830315225
# F1 Score: 0.8715722024323925

# %% [markdown]
# #### predict the o/p for validation data

# %%
val_df =pd.read_csv('validation_data_to_be_shared 3/validation_data_to_be_shared.csv')
val_df.head(5)
# Out:
#    account_number  onus_attribute_1  transaction_attribute_1  \
# 0          100001           34000.0                      0.0
# 1          100002               NaN                      NaN
# 2          100003          130000.0                      0.0
# 3          100004               NaN                      NaN
# 4          100005           53000.0                      0.0
#
#    transaction_attribute_2  transaction_attribute_3  transaction_attribute_4  \
# 0                      0.0                      0.0                      0.0
# 1                      NaN                      NaN                      NaN
# 2                      0.0                      0.0                      0.0
# 3                      NaN                      NaN                      NaN
# 4                      0.0                      0.0                      0.0
#
#    transaction_attribute_5  transaction_attribute_6  transaction_attribute_7  \
# ...

# %%
val_df.isnull().sum()
# Out:
# account_number                 0
# onus_attribute_1           10990
# transaction_attribute_1    10990
# transaction_attribute_2    10990
# transaction_attribute_3    10990
#                            ...
# onus_attribute_44          36789
# onus_attribute_45          36789
# onus_attribute_46          36789
# onus_attribute_47          36789
# onus_attribute_48          36789
# Length: 1215, dtype: int64

# %%
col_group = ['onus_attribute_','transaction_attribute_','bureau_enquiry_','bureau_']
df_sum = pd.DataFrame()

for group in col_group:
    
    #select the colummns which startswith similar name
    selected_column = [col for col in X_resampled.columns if col.startswith(group)]

    #sum those values of that columns
    df_sum[group] = val_df[selected_column].sum(axis=1)


print(df_sum.shape)
df_sum.head(4)
# Out:
# (41792, 4)
#    onus_attribute_  transaction_attribute_  bureau_enquiry_       bureau_
# 0     37101.150258           918989.806363            288.0  3.559466e+06
# 1      -669.244656                0.000000              0.0  2.325515e+07
# 2    130069.379340           471394.200527            127.0  8.470840e+06
# 3        90.414912                0.000000              9.0  1.715626e+06

# %%
df_sum=df_sum.fillna(0)

# %%
df_scaled_sum = scaler.transform(df_sum)

# %%
y_val_pred = ensemble_model.predict(df_scaled_sum)
y_val_pred
# Out:
# array([1, 0, 0, ..., 0, 0, 1], dtype=int64)

# %%
df_sum['bad_flag'] = y_val_pred
df_sum.head()
# Out:
#    onus_attribute_  transaction_attribute_  bureau_enquiry_       bureau_  \
# 0     37101.150258           918989.806363            288.0  3.559466e+06
# 1      -669.244656                0.000000              0.0  2.325515e+07
# 2    130069.379340           471394.200527            127.0  8.470840e+06
# 3        90.414912                0.000000              9.0  1.715626e+06
# 4     82776.194431           900470.348830            236.0  1.764241e+06
#
#    bad_flag
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0

# %%
df_sum['bad_flag'].value_counts()
# Out:
# bad_flag
# 0    38823
# 1     2969
# Name: count, dtype: int64

# %% [markdown]
# ### Visualising the validation data for exploring the insights

# %%
sns.histplot(df_sum['onus_attribute_'], kde=True)
plt.title('Distribution of Onus Attribute')
plt.xlabel('Onus Attribute')
plt.ylabel('Frequency')
plt.show()

sns.histplot(df_sum['transaction_attribute_'], kde=True)
plt.title('Distribution of Transaction Attribute')
plt.xlabel('Transaction Attribute')
plt.ylabel('Frequency')
plt.show()

# ... similar plots for 'bureau_enquiry' and 'bureau'
sns.histplot(df_sum['bureau_enquiry_'], kde=True)
plt.title('Distribution of PL enquires in last 3 months')
plt.xlabel('enquiries')
plt.ylabel('Frequency')
plt.show()

sns.histplot(df_sum['bureau_'], kde=True)
plt.title('Distribution of product holdings and historical delinquices')
plt.xlabel('bureau')
plt.ylabel('Frequency')
plt.show()

#df_sum.to_csv('submission.csv', index=False)

# %%
sns.boxplot(x='bad_flag', y='onus_attribute_', data=df_sum)
plt.title('Onus Attribute vs Bad Flag')
plt.ylabel('Onus Attribute')
plt.xlabel('Bad Flag')
plt.show()

sns.boxplot(x='bad_flag', y='transaction_attribute_', data=df_sum)
plt.title('Onus Attribute vs Bad Flag')
plt.ylabel('Transaction Attribute')
plt.xlabel('Bad Flag')
plt.show()

sns.boxplot(x='bad_flag', y='bureau_enquiry_', data=df_sum)
plt.title('Onus Attribute vs Bad Flag')
plt.ylabel('Bureau Enquiry')
plt.xlabel('Bad Flag')
plt.show()

sns.boxplot(x='bad_flag', y='bureau_', data=df_sum)
plt.title('Onus Attribute vs Bad Flag')
plt.ylabel('Bureau')
plt.xlabel('Bad Flag')
plt.show()

# %%
#Heatmap

sns.heatmap(df_sum.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
#  scatter plots for onus_sttribute and other columns
sns.scatterplot(x='onus_attribute_', y='transaction_attribute_', hue='bad_flag', data=df_sum)
plt.title('Onus Attribute vs Transaction Attribute by Bad Flag')
plt.xlabel('Onus Attribute')
plt.ylabel('Transaction Attribute')
plt.show()


sns.scatterplot(x='onus_attribute_', y='bureau_enquiry_', hue='bad_flag', data=df_sum)
plt.title('Onus Attribute vs bureau enquiry by Bad Flag')
plt.xlabel('Onus Attribute')
plt.ylabel('Bureau enquiry')
plt.show()

sns.scatterplot(x='onus_attribute_', y='bureau_', hue='bad_flag', data=df_sum)
plt.title('Onus Attribute vs bureau by Bad Flag')
plt.xlabel('Onus Attribute')
plt.ylabel('bureau')
plt.show()

#  scatter plots for transaction_sttribute and other columns
sns.scatterplot(y='bureau_', x='transaction_attribute_', hue='bad_flag', data=df_sum)
plt.title('Bureau vs Transaction Attribute by Bad Flag')
plt.xlabel('Transaction Attribute')
plt.ylabel('Bureau')
plt.show()

sns.scatterplot(y='bureau_enquiry_', x='transaction_attribute_', hue='bad_flag', data=df_sum)
plt.title('Bureau enquiry vs Transaction Attribute by Bad Flag')
plt.ylabel('Bureau Enquiry')
plt.xlabel('Transaction Attribute')
plt.show()

#  scatter plots for bureau_enquiry and other columns
sns.scatterplot(y='bureau_enquiry_', x='bureau_', hue='bad_flag', data=df_sum)
plt.title('Bureau enquiry vs Bureau by Bad Flag')
plt.ylabel('Bureau Enquiry')
plt.xlabel('Bureau')
# Out:
# Text(0.5, 0, 'Bureau')

# %%
new_df=pd.DataFrame()
new_df['account_number']=val_df['account_number']
new_df['bad_flag']=y_val_pred

# %%
new_df.head()
# Out:
#    account_number  bad_flag
# 0          100001         1
# 1          100002         0
# 2          100003         0
# 3          100004         0
# 4          100005         0

# %%
new_df.to_csv('submission.csv', index=False)
